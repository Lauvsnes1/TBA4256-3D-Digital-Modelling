# %%
import laspy
import numpy as np
import open3d as o3d




def RANSAC(xyz: np.ndarray, iteration: int):
    '''
    returns a points that are close to a randomly found plane
    '''
    def plane_from_three_points(p1, p2, p3):
        v1 = p2 - p1
        v2 = p3 - p1
        cp = np.cross(v1, v2)
        # a, b, c = cp[0]
        d = np.dot(cp, p2)[0]
        return cp, d

    def calculate_plane_angle(cp):
        return np.degrees(np.arccos(cp[0][2]/np.sqrt(np.sum(cp**2))))

    def calculate_close_points(points, distances, max_distance, min_distance = -1):
        all_close = distances <= max_distance
        if min_distance > 0:
            inner = distances >= min_distance
            return points[np.logical_and(all_close, inner)]
        return points[all_close]

    def region_grow_plane(rand_point, close_plane_points: np.array):

        def point_str(point):
            return str(point[0]) + ',' + str(point[1]) + ',' + str(point[2])

        region_points = np.zeros((1,3))
        neighbour_points = np.array(rand_point)
        all_neighbour_points_dict = {}
        all_neighbour_points_dict[point_str(rand_point[0])] = True

        # Loop through the points and add them to the region points if they are close to another open region point
        while neighbour_points.shape[0] != 0:
            # Take out the first point of the neighbour_points and add it to region_points
            neighbour = neighbour_points[0]
            neighbour_points = np.delete(neighbour_points, 0, axis=0)
            region_points = np.append(region_points, np.array([neighbour]), axis=0)

            # Calculate distances from the neighbour
            # TODO: Try different distances! Not just 50cm
            max_neighbour_distance = 0.4 # 40cm
            distances = np.sqrt(np.sum((close_plane_points - np.array([neighbour]))**2, axis=1))
            close_to_neighbour = calculate_close_points(close_plane_points, distances, max_neighbour_distance)

            # Add new neighbours to neighbour_points that are 
            # not already in neighbour_points or region_points
            for close in close_to_neighbour:
                # if not (close in neighbour_points or close in region_points):
                if not point_str(close) in all_neighbour_points_dict:
                    neighbour_points = np.append(neighbour_points, np.array([close]), axis=0)
                    all_neighbour_points_dict[point_str(close)] = True

        # Remove the first point, as it is the zero-point
        region_points = np.delete(region_points, 0, axis=0)

        # region_points[str(rand_point[0]) + str(rand_point[1]) + str(rand_point[2])]
        return region_points

    # Find random point
    indx = np.random.randint(0, xyz.shape[0], 1)
    rand_point = xyz[indx]

    # Calculate distances from rand_point
    point_distances = np.sqrt(np.sum((xyz - rand_point)**2, axis=1))

    # Only keep points that are close but not too close
    max_point_distance = 1.5  # 1.5m
    min_point_distance = 1.0  # 1m
    close_points = calculate_close_points(xyz, point_distances, max_point_distance, min_point_distance)

    # If not enough close points, try again
    if close_points.shape[0] <= 1:
        print('No close points to rand_point')
        return RANSAC(xyz, iteration+1)

    # Find 2 other random points that are close to the rand_point, and that are not the same
    other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
    other_points = close_points[other_indxs]

    # Check if the plane has a good angle
    cp, _ = plane_from_three_points(
        rand_point, other_points[0], other_points[1])

    # If the denominator is zero, start RANSAC again
    if np.abs(np.sum(cp**2, axis=1)) < 0.0001:
        print('Denominator is zero')
        return RANSAC(xyz, iteration+1)

    # If the angle of the plane is not suitable, start RANSAC again
    # Suitable roof angles: between 15 and 60, over 90deg? remove 90 from it. negative? use abs.
    plane_angle = np.abs(calculate_plane_angle(cp))

    # Check if plane angle is suitable for a roof, else start RANSAC again
    if 15 > plane_angle or plane_angle > 60:
        print('Bad plane_angle')
        return RANSAC(xyz, iteration+1)

    # We do now know that we can construct a good plane from this rand_point
    # Extract a medium-large area
    max_area_distance = 40 # 40m

    # Use point_distancec which is defined from the rand_point above
    area_points = calculate_close_points(xyz, point_distances, max_area_distance)

    # Region grow from the rand_point on the area to only include the roof
    region_points = region_grow_plane(rand_point, area_points)

    # Check if the region has to few points, else start RANSAC again
    if region_points.shape[0] < 2000:
        print('Too few points in region:', region_points.shape[0])
        return RANSAC(xyz, iteration+1)


    # Class to store planes
    class Plane():
        def __init__(self, points: np.ndarray, angle: float):
            self.points = points
            self.angle = angle
        
        def __gt__(self, other):
            return self.points.shape[0] > other.points.shape[0]

    # Perform RANSAC on the region
    saved_ransac_roofs = np.array([Plane(np.zeros((1,3)), angle=0)], dtype=Plane)
    ransac_tot_runs = 50
    ransac_run_num = 0

    # TODO: Test different values
    max_plane_distance = 0.5  # 50cm

    
    while ransac_run_num < ransac_tot_runs:
        rand_indxs = np.random.choice(region_points.shape[0], 3, replace=False)
        rand_points = region_points[rand_indxs]

        ransac_cp, ransac_d = plane_from_three_points(np.array([rand_points[0]]), rand_points[1], rand_points[2])

        # If the denominator is zero, loop again
        if np.abs(np.sum(ransac_cp**2, axis=1)) < 0.0001:
            continue
        
        ransac_plane_angle = np.abs(calculate_plane_angle(ransac_cp))

        # Check if plane angle is not suitable for a roof, loop again
        if 15 > ransac_plane_angle or ransac_plane_angle > 60:
            continue

        # Calculate which points are in the plane
        ransac_plane_distances = np.abs(np.sum(ransac_cp*region_points, axis=1) - ransac_d) / np.sqrt(np.sum(ransac_cp**2, axis=1))
        ransac_plane_points = calculate_close_points(region_points, ransac_plane_distances, max_plane_distance)

        saved_ransac_roofs = np.append(saved_ransac_roofs, Plane(ransac_plane_points, ransac_plane_angle))

        ransac_run_num += 1


    # Coose the ransac_roof with the most points
    best_roof_index = np.argmax(saved_ransac_roofs)
    best_roof = saved_ransac_roofs[best_roof_index]
    
    if best_roof.points.shape[0] < 800:
        print('Too few points in best_roof:', best_roof.points.shape[0])
        return RANSAC(xyz, iteration+1)

    return best_roof.points, iteration # region_points, iteration #  


# # # Read the data and preprocess it
dataFile = laspy.read("data.laz")

xyz = pre_processing(dataFile)


# # # Do RANSAC several times and save the results
roofs = np.zeros((1,3))
for i in range(40):
    RANSAC_points, iterations = RANSAC(xyz, 0)
    print('------- DONE -------')
    print('Info about roof numer:', i + 1)
    print('Total iterations in RANSAC         : ' + str(iterations))
    print('Total number of points after RANSAC: ' + str(RANSAC_points.shape[0]))

    # Elevate roof points to make them visible
    RANSAC_points = RANSAC_points + [0, 0, 0.01]
    roofs = np.append(roofs, RANSAC_points, axis=0)

roofs = np.delete(roofs, 0, axis=0)
print(roofs.shape)
# # # Show the points
cloud = o3d.geometry.PointCloud()
cloud.points = o3d.utility.Vector3dVector(xyz)
cloud.paint_uniform_color([0.1, 0.1, 0.1])

roof = o3d.geometry.PointCloud()
roof.points = o3d.utility.Vector3dVector(roofs)
roof.paint_uniform_color([0.9, 0.1, 0.1])


o3d.visualization.draw_geometries([cloud, roofs])


# , point_show_normal=True)

'''
------- DONE -------
Info about roof numer: 1
Total iterations in RANSAC         : 27
Total number of points after RANSAC: 1792

------- DONE -------
Info about roof numer: 2
Total iterations in RANSAC         : 21
Total number of points after RANSAC: 858

------- DONE -------
Info about roof numer: 3
Total iterations in RANSAC         : 35
Total number of points after RANSAC: 2303

------- DONE -------
Info about roof numer: 4
Total iterations in RANSAC         : 9
Total number of points after RANSAC: 3022

------- DONE -------
Info about roof numer: 5
Total iterations in RANSAC         : 6
Total number of points after RANSAC: 2814

------- DONE -------
Info about roof numer: 6
Total iterations in RANSAC         : 67
Total number of points after RANSAC: 1792

------- DONE -------
Info about roof numer: 7
Total iterations in RANSAC         : 25
Total number of points after RANSAC: 3063

------- DONE -------
Info about roof numer: 8
Total iterations in RANSAC         : 77
Total number of points after RANSAC: 1005

------- DONE -------
Info about roof numer: 9
Total iterations in RANSAC         : 18
Total number of points after RANSAC: 2123

------- DONE -------
Info about roof numer: 10
Total iterations in RANSAC         : 36
Total number of points after RANSAC: 2194

------- DONE -------
Info about roof numer: 11
Total iterations in RANSAC         : 40
Total number of points after RANSAC: 955

------- DONE -------
Info about roof numer: 12
Total iterations in RANSAC         : 23
Total number of points after RANSAC: 4690

------- DONE -------
Info about roof numer: 13
Total iterations in RANSAC         : 2
Total number of points after RANSAC: 2689

------- DONE -------
Info about roof numer: 14
Total iterations in RANSAC         : 3
Total number of points after RANSAC: 2803

------- DONE -------
Info about roof numer: 15
Total iterations in RANSAC         : 11
Total number of points after RANSAC: 1633

------- DONE -------
Info about roof numer: 16
Total iterations in RANSAC         : 5
Total number of points after RANSAC: 1322

------- DONE -------
Info about roof numer: 17
Total iterations in RANSAC         : 78
Total number of points after RANSAC: 3056

------- DONE -------
Info about roof numer: 18
Total iterations in RANSAC         : 3
Total number of points after RANSAC: 2068

------- DONE -------
Info about roof numer: 19
Total iterations in RANSAC         : 31
Total number of points after RANSAC: 4178

------- DONE -------
Info about roof numer: 20
Total iterations in RANSAC         : 10
Total number of points after RANSAC: 2206

(46566, 3)

Total iterations in RANSAC IN TOTAL: 527 + 20
'''



'''
------- DONE -------
Info about roof numer: 1
Total iterations in RANSAC         : 18
Total number of points after RANSAC: 2049


------- DONE -------
Info about roof numer: 2
Total iterations in RANSAC         : 47
Total number of points after RANSAC: 2885


------- DONE -------
Info about roof numer: 3
Total iterations in RANSAC         : 14
Total number of points after RANSAC: 3373


------- DONE -------
Info about roof numer: 4
Total iterations in RANSAC         : 35
Total number of points after RANSAC: 2133


------- DONE -------
Info about roof numer: 5
Total iterations in RANSAC         : 0
Total number of points after RANSAC: 2200


------- DONE -------
Info about roof numer: 6
Total iterations in RANSAC         : 14
Total number of points after RANSAC: 3441


------- DONE -------
Info about roof numer: 7
Total iterations in RANSAC         : 32
Total number of points after RANSAC: 2342


------- DONE -------
Info about roof numer: 8
Total iterations in RANSAC         : 3
Total number of points after RANSAC: 1159


------- DONE -------
Info about roof numer: 9
Total iterations in RANSAC         : 11
Total number of points after RANSAC: 1094


------- DONE -------
Info about roof numer: 10
Total iterations in RANSAC         : 22
Total number of points after RANSAC: 3202


------- DONE -------
Info about roof numer: 11
Total iterations in RANSAC         : 16
Total number of points after RANSAC: 1603


------- DONE -------
Info about roof numer: 12
Total iterations in RANSAC         : 140
Total number of points after RANSAC: 3284


------- DONE -------
Info about roof numer: 13
Total iterations in RANSAC         : 63
Total number of points after RANSAC: 3284


------- DONE -------
Info about roof numer: 14
Total iterations in RANSAC         : 7
Total number of points after RANSAC: 2166


------- DONE -------
Info about roof numer: 15
Total iterations in RANSAC         : 4
Total number of points after RANSAC: 2828


------- DONE -------
Info about roof numer: 16
Total iterations in RANSAC         : 30
Total number of points after RANSAC: 3154


------- DONE -------
Info about roof numer: 17
Total iterations in RANSAC         : 3
Total number of points after RANSAC: 2500


------- DONE -------
Info about roof numer: 18
Total iterations in RANSAC         : 0
Total number of points after RANSAC: 2223


------- DONE -------
Info about roof numer: 19
Total iterations in RANSAC         : 22
Total number of points after RANSAC: 3085


------- DONE -------
Info about roof numer: 20
Total iterations in RANSAC         : 17
Total number of points after RANSAC: 2658

(50663, 3)

Total iterations in RANSAC IN TOTAL: 495 + 20


Both totals summarized: 547 + 515 = 1062

Average number of iterations: 26.5
'''
# Out:
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 1
# Denominator is zero
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 6
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 6
# No close points to rand_point
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 6
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 3
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 3
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 2
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 5
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 4
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 10
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Too few points in region: 3
# Too few points in region: 1
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 2
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 7
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 10
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 5
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 3
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 2
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 6
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 4
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 3
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 3
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 4
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 4
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Too few points in region: 6
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 4
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 7
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 3
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 6
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# No close points to rand_point
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# No close points to rand_point
# ...
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 6
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Too few points in region: 1
# Too few points in region: 1
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 1
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Too few points in region: 1
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 5
# Bad plane_angle
# Too few points in region: 3
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Too few points in region: 4
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 6
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 1
# Too few points in region: 1
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 10
# Too few points in region: 1
# Too few points in region: 2
# Too few points in region: 4
# Bad plane_angle
# Too few points in region: 1
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 2
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 3
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# Bad plane_angle
# No close points to rand_point
# Bad plane_angle
# Too few points in region: 5
# Bad plane_angle
# Bad plane_angle
# Too few points in region: 4
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[3], line 195
#     193 roofs = np.zeros((1,3))
#     194 for i in range(40):
# --> 195     RANSAC_points, iterations = RANSAC(xyz, 0)
#     196     print('------- DONE -------')
#     197     print('Info about roof numer:', i + 1)
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
#     [... skipping similar frames: RANSAC at line 114 (1 times)]
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
#     [... skipping similar frames: RANSAC at line 114 (1 times)]
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
#     [... skipping similar frames: RANSAC at line 114 (11 times), RANSAC at line 129 (3 times)]
#
# Cell In[3], line 92, in RANSAC(xyz, iteration)
#      90 if close_points.shape[0] <= 1:
#      91     print('No close points to rand_point')
# ---> 92     return RANSAC(xyz, iteration+1)
#      94 # Find 2 other random points that are close to the rand_point, and that are not the same
#      95 other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
#
#     [... skipping similar frames: RANSAC at line 114 (3 times)]
#
# Cell In[3], line 92, in RANSAC(xyz, iteration)
#      90 if close_points.shape[0] <= 1:
#      91     print('No close points to rand_point')
# ---> 92     return RANSAC(xyz, iteration+1)
#      94 # Find 2 other random points that are close to the rand_point, and that are not the same
#      95 other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
#
#     [... skipping similar frames: RANSAC at line 114 (5 times), RANSAC at line 129 (4 times)]
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
# Cell In[3], line 105, in RANSAC(xyz, iteration)
#     103 if np.abs(np.sum(cp**2, axis=1)) < 0.0001:
#     104     print('Denominator is zero')
# --> 105     return RANSAC(xyz, iteration+1)
#     107 # If the angle of the plane is not suitable, start RANSAC again
#     108 # Suitable roof angles: between 15 and 60, over 90deg? remove 90 from it. negative? use abs.
#     109 plane_angle = np.abs(calculate_plane_angle(cp))
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
#     [... skipping similar frames: RANSAC at line 114 (67 times), RANSAC at line 129 (15 times)]
#
# Cell In[3], line 92, in RANSAC(xyz, iteration)
#      90 if close_points.shape[0] <= 1:
#      91     print('No close points to rand_point')
# ---> 92     return RANSAC(xyz, iteration+1)
#      94 # Find 2 other random points that are close to the rand_point, and that are not the same
#      95 other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
#
#     [... skipping similar frames: RANSAC at line 114 (9 times), RANSAC at line 129 (4 times)]
#
# Cell In[3], line 92, in RANSAC(xyz, iteration)
#      90 if close_points.shape[0] <= 1:
#      91     print('No close points to rand_point')
# ---> 92     return RANSAC(xyz, iteration+1)
#      94 # Find 2 other random points that are close to the rand_point, and that are not the same
#      95 other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
#
#     [... skipping similar frames: RANSAC at line 114 (2086 times), RANSAC at line 129 (610 times), RANSAC at line 92 (127 times)]
#
# Cell In[3], line 92, in RANSAC(xyz, iteration)
#      90 if close_points.shape[0] <= 1:
#      91     print('No close points to rand_point')
# ---> 92     return RANSAC(xyz, iteration+1)
#      94 # Find 2 other random points that are close to the rand_point, and that are not the same
#      95 other_indxs = np.random.choice(close_points.shape[0], 2, replace=False)
#
#     [... skipping similar frames: RANSAC at line 114 (2 times), RANSAC at line 129 (1 times)]
#
# Cell In[3], line 114, in RANSAC(xyz, iteration)
#     112 if 15 > plane_angle or plane_angle > 60:
#     113     print('Bad plane_angle')
# --> 114     return RANSAC(xyz, iteration+1)
#     116 # We do now know that we can construct a good plane from this rand_point
#     117 # Extract a medium-large area
#     118 max_area_distance = 40 # 40m
#
# Cell In[3], line 129, in RANSAC(xyz, iteration)
#     127 if region_points.shape[0] < 2000:
#     128     print('Too few points in region:', region_points.shape[0])
# --> 129     return RANSAC(xyz, iteration+1)
#     132 # Class to store planes
#     133 class Plane():
#
# Cell In[3], line 99, in RANSAC(xyz, iteration)
#      96 other_points = close_points[other_indxs]
#      98 # Check if the plane has a good angle
# ---> 99 cp, _ = plane_from_three_points(
#     100     rand_point, other_points[0], other_points[1])
#     102 # If the denominator is zero, start RANSAC again
#     103 if np.abs(np.sum(cp**2, axis=1)) < 0.0001:
#
# Cell In[3], line 25, in RANSAC.<locals>.plane_from_three_points(p1, p2, p3)
#      23 v1 = p2 - p1
#      24 v2 = p3 - p1
# ---> 25 cp = np.cross(v1, v2)
#      26 # a, b, c = cp[0]
#      27 d = np.dot(cp, p2)[0]
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/numeric.py:1591, in cross(a, b, axisa, axisb, axisc, axis)
#    1588 axisb = normalize_axis_index(axisb, b.ndim, msg_prefix='axisb')
#    1590 # Move working axis to the end of the shape
# -> 1591 a = moveaxis(a, axisa, -1)
#    1592 b = moveaxis(b, axisb, -1)
#    1593 msg = ("incompatible dimensions for cross product\n"
#    1594        "(dimension must be 2 or 3)")
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/numeric.py:1449, in moveaxis(a, source, destination)
#    1446     a = asarray(a)
#    1447     transpose = a.transpose
# -> 1449 source = normalize_axis_tuple(source, a.ndim, 'source')
#    1450 destination = normalize_axis_tuple(destination, a.ndim, 'destination')
#    1451 if len(source) != len(destination):
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/numeric.py:1380, in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1378         pass
#    1379 # Going via an iterator directly is slower than via list comprehension.
# -> 1380 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1381 if not allow_duplicate and len(set(axis)) != len(axis):
#    1382     if argname:
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/numpy/core/numeric.py:1380, in <listcomp>(.0)
#    1378         pass
#    1379 # Going via an iterator directly is slower than via list comprehension.
# -> 1380 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1381 if not allow_duplicate and len(set(axis)) != len(axis):
#    1382     if argname:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
